# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as ny

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID", axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0         True
# 1     35            20000          0         True
# 2     26            43000          0        False
# 3     27            57000          0        False
# 4     19            76000          0         True
# ..   ...              ...        ...          ...
# 395   46            41000          1        False
# 396   51            23000          1         True
# 397   50            20000          1        False
# 398   36            33000          0         True
# 399   49            36000          1        False
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
indep=dataset[['Age', 'EstimatedSalary', 'Gender_Male']]

# %%
dep=dataset['Purchased']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep, dep, test_size=1/3, random_state=0)

# %%
indep.shape
# Out:
# (400, 3)

# %%
dep
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.svm import SVC

from sklearn.model_selection import GridSearchCV

param_grid={'kernel':['rbf', 'linear', 'poly', 'sigmoid'], 'C':[10,100,1000,2000,3000], 'gamma':['auto','scale']}

grid=GridSearchCV(SVC(probability=True), param_grid, refit=True, verbose=3, cv=5, n_jobs=-1, scoring='f1_weighted')
#to tune a model
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'linear', 'poly', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
#to know the best tune parameter
re = grid.cv_results_
#print(re)

grid_prediction=grid.predict(x_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_prediction)

from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_prediction)
print(clf_report)
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        85
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134
#
# [[80  5]
#  [ 7 42]]

# %%
#to know the f1 score
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test, grid_prediction, average='weighted')
print("The f1_macro value of best parameter is {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value of best parameter is {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9100355779243318

# %%
#as a addition to know a receiver operator characteristic area under curve value to identify best classification
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, grid.predict_proba(x_test)[:,-1])
# Out:
# 0.9539015606242497

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.027343      0.003621         0.010831        0.002968      10
# 1        0.028499      0.003505         0.008210        0.001672      10
# 2        0.031196      0.003920         0.007818        0.002257      10
# 3        0.018599      0.002456         0.008264        0.001847      10
# 4        0.023855      0.002727         0.008628        0.001527      10
# 5        0.026689      0.004589         0.007359        0.001411      10
# 6        0.022646      0.003010         0.007383        0.002059      10
# 7        0.014958      0.001988         0.007292        0.000816      10
# 8        0.025691      0.002457         0.007565        0.001607     100
# 9        0.088363      0.003744         0.008286        0.001058     100
# 10       0.106369      0.023716         0.007684        0.001557     100
# 11       0.016254      0.001822         0.008016        0.000706     100
# 12       0.029579      0.005893         0.007909        0.001375     100
# 13       0.081102      0.016287         0.006688        0.001304     100
# 14       0.117229      0.042891         0.007041        0.001879     100
# 15       0.015457      0.003694         0.009782        0.004184     100
# 16       0.074966      0.007855         0.006718        0.000813    1000
# 17       0.682631      0.129822         0.007012        0.000806    1000
# 18       0.893207      0.256419         0.006093        0.001378    1000
# 19       0.015943      0.002534         0.008131        0.000655    1000
# 20       0.082782      0.009884         0.007852        0.001176    1000
# 21       0.630581      0.094059         0.007500        0.000753    1000
# 22       0.999783      0.332197         0.005796        0.001861    1000
# 23       0.017058      0.002945         0.006261        0.000718    1000
# 24       0.126070      0.023367         0.007125        0.001629    2000
# 25       1.703999      0.545662         0.008127        0.001239    2000
# 26       2.097584      0.544183         0.008023        0.001732    2000
# 27       0.018773      0.002405         0.008217        0.000742    2000
# 28       0.164597      0.023782         0.007635        0.000883    2000
# 29       1.426466      0.287897         0.007105        0.003008    2000
# 30       1.940881      0.449972         0.008064        0.000856    2000
# 31       0.018691      0.006431         0.007492        0.000826    2000
# 32       0.209550      0.033769         0.009608        0.000781    3000
# 33       1.825127      0.259286         0.008554        0.000856    3000
# 34       3.339204      1.526444         0.006120        0.002365    3000
# 35       0.017583      0.003432         0.006090        0.002407    3000
# 36       0.212870      0.039181         0.009425        0.000765    3000
# 37       1.993743      0.343049         0.008824        0.000457    3000
# 38       2.635250      0.934949         0.007839        0.001470    3000
# 39       0.017630      0.000691         0.006804        0.002006    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto       linear
# 2         auto         poly
# 3         auto      sigmoid
# 4        scale          rbf
# 5        scale       linear
# 6        scale         poly
# 7        scale      sigmoid
# 8         auto          rbf
# 9         auto       linear
# 10        auto         poly
# 11        auto      sigmoid
# 12       scale          rbf
# 13       scale       linear
# 14       scale         poly
# 15       scale      sigmoid
# 16        auto          rbf
# 17        auto       linear
# 18        auto         poly
# 19        auto      sigmoid
# 20       scale          rbf
# 21       scale       linear
# 22       scale         poly
# 23       scale      sigmoid
# 24        auto          rbf
# 25        auto       linear
# 26        auto         poly
# 27        auto      sigmoid
# 28       scale          rbf
# 29       scale       linear
# 30       scale         poly
# 31       scale      sigmoid
# 32        auto          rbf
# 33        auto       linear
# 34        auto         poly
# 35        auto      sigmoid
# 36       scale          rbf
# 37       scale       linear
# 38       scale         poly
# 39       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 1      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 2        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.799620
# 3     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.762677
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 6       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.799620
# 7    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.762677
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 9     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 10      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 11   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.808927
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 13   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 14     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 15  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.808927
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 17   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 18     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 19  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.847141
# 21  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 22    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 25   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 26     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 27  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 29  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 30    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 33   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 34     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 35  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 37  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 38    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.886792           0.869709           0.944161
# 1            0.790949           0.698235           0.923510
# 2            0.808392           0.787943           0.924528
# 3            0.738916           0.655795           0.796284
# 4            0.886792           0.869709           0.944161
# 5            0.790949           0.698235           0.923510
# 6            0.808392           0.787943           0.924528
# 7            0.738916           0.753180           0.778067
# 8            0.886792           0.870362           0.944161
# 9            0.790949           0.698235           0.923510
# 10           0.787284           0.766556           0.924528
# 11           0.714931           0.633719           0.718497
# 12           0.886792           0.870362           0.944161
# 13           0.790949           0.698235           0.923510
# 14           0.787284           0.766556           0.924528
# 15           0.714931           0.698113           0.796284
# 16           0.866968           0.851527           0.925272
# 17           0.790949           0.698235           0.923510
# 18           0.765553           0.766556           0.924528
# 19           0.714931           0.698113           0.796284
# 20           0.866968           0.851527           0.925272
# 21           0.790949           0.698235           0.923510
# 22           0.765553           0.766556           0.924528
# 23           0.714931           0.698113           0.796284
# 24           0.866968           0.851527           0.886792
# 25           0.790949           0.698235           0.923510
# 26           0.765553           0.766556           0.924528
# 27           0.714931           0.698113           0.796284
# 28           0.866968           0.851527           0.886792
# 29           0.790949           0.698235           0.923510
# 30           0.765553           0.766556           0.924528
# 31           0.714931           0.698113           0.796284
# 32           0.866968           0.851527           0.847020
# 33           0.790949           0.698235           0.923510
# 34           0.765553           0.766556           0.924528
# 35           0.714931           0.698113           0.796284
# 36           0.866968           0.851527           0.847020
# 37           0.790949           0.698235           0.923510
# 38           0.765553           0.766556           0.924528
# 39           0.714931           0.698113           0.796284
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.943041         0.902236        0.034431                3
# 1            0.901744         0.818146        0.083619               21
# 2            0.901744         0.844445        0.056918               11
# 3            0.766556         0.744045        0.047743               39
# 4            0.943041         0.902236        0.034431                3
# 5            0.901744         0.818146        0.083619               21
# 6            0.901744         0.844445        0.056918               11
# 7            0.766556         0.759879        0.013172               31
# 8            0.943041         0.902367        0.034308                1
# 9            0.901744         0.818146        0.083619               21
# 10           0.901744         0.840441        0.062370               13
# 11           0.766556         0.728526        0.058625               40
# 12           0.943041         0.902367        0.034308                1
# 13           0.901744         0.818146        0.083619               21
# 14           0.901744         0.840441        0.062370               13
# 15           0.766556         0.756962        0.043745               32
# 16           0.923510         0.878708        0.039503                6
# 17           0.901744         0.818146        0.083619               21
# 18           0.901744         0.836095        0.066541               15
# 19           0.766556         0.753527        0.040048               36
# 20           0.923510         0.882884        0.034529                5
# 21           0.901744         0.818146        0.083619               21
# 22           0.901744         0.836095        0.066541               15
# 23           0.766556         0.756962        0.043745               32
# 24           0.903610         0.867032        0.026948                7
# 25           0.901744         0.818146        0.083619               21
# 26           0.901744         0.836095        0.066541               15
# 27           0.766556         0.753527        0.040048               36
# 28           0.903610         0.867032        0.026948                7
# 29           0.901744         0.818146        0.083619               21
# 30           0.901744         0.836095        0.066541               15
# 31           0.766556         0.756962        0.043745               32
# 32           0.883278         0.855011        0.019206                9
# 33           0.901744         0.818146        0.083619               21
# 34           0.901744         0.836095        0.066541               15
# 35           0.766556         0.753527        0.040048               36
# 36           0.883278         0.855011        0.019206                9
# 37           0.901744         0.818146        0.083619               21
# 38           0.901744         0.836095        0.066541               15
# 39           0.766556         0.756962        0.043745               32

# %%
age_input=float(input('Age'))
EstimatedSalary_input=float(input('EstimatedSalary'))
Gender_Male_input=float(input('Gender_Male'))
# Out:
# Age 26
# EstimatedSalary 80000
# Gender_Male 1

# %%
grid.predict([[age_input, EstimatedSalary_input, Gender_Male_input]])
# Out:
# array([1], dtype=int64)
